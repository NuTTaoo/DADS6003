# %% [markdown]
# <a href="https://colab.research.google.com/github/NuTTaoo/DADS6003/blob/main/DADS_5001__Practice_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# PRACTICE
# 1. (1 point) Display pokedex number, English name, Japanese name, and hp values regarding all 1st-generation pokemons. The results must be ordered starting from the maximum hp to the minimum hp (for the same hp value, order by the pokedex number from small to large).
#
# 2. (1 point) How many pokemons that both type1 and type2 are not NA, and have type1 of either water or grass?
#
# 3. (1.5 points) Display pokedex number, English name, hp, abilities, and capture rate values regarding all pokemons whose abilities attribute includes 'super luck' and whose capture rate is greater than 90.

# %%
#PRACTICE_1
import sys
import pandas as pd
import numpy as np
df_pokemon = pd.read_csv('https://raw.githubusercontent.com/ShaileshDhama/Exploratory-Data-Analysis-On-Pokemon-Dataset/master/Complete%20Pokemon.csv') #Read มากจาก Github
df_pokemon.shape
df = df_pokemon

# %%
#1
df.loc[df['generation'] == 1, ['pokedex_number', 'name', 'japanese_name', 'hp', 'generation']].sort_values(by=['hp', 'pokedex_number'], ascending=[False, True]).reset_index(drop=True)
# Out:
#      pokedex_number        name japanese_name   hp  generation
# 0               113     Chansey     Luckyラッキー  250           1
# 1               143     Snorlax   Kabigonカビゴン  160           1
# 2                40  Wigglytuff   Pukurinプクリン  140           1
# 3               131      Lapras   Laplaceラプラス  130           1
# 4               134    Vaporeon  Showersシャワーズ  130           1
# ..              ...         ...           ...  ...         ...
# 146             140      Kabuto     Kabutoカブト   30           1
# 147              63        Abra     Caseyケーシィ   25           1
# 148              81   Magnemite       Coilコイル   25           1
# 149             129    Magikarp  Koikingコイキング   20           1
# 150              50     Diglett     Digdaディグダ   10           1
#
# [151 rows x 5 columns]

# %%
#2
df.loc[ ((df['type1'] == 'water') | (df['type1'] == 'grass')) & (df['type2'].notna()), ['name', 'type1', 'type2']]
# Out:
#           name  type1    type2
# 0    Bulbasaur  grass   poison
# 1      Ivysaur  grass   poison
# 2     Venusaur  grass   poison
# 42      Oddish  grass   poison
# 43       Gloom  grass   poison
# ..         ...    ...      ...
# 755  Shiinotic  grass    fairy
# 778    Bruxish  water  psychic
# 786  Tapu Bulu  grass    fairy
# 787  Tapu Fini  water    fairy
# 797    Kartana  grass    steel
#
# [94 rows x 3 columns]

# %%
#3
df['capture_rate'] = pd.to_numeric(df['capture_rate'], errors='coerce')
df.loc [ (df['abilities'].str.contains('super luck', case=False)) & (df['capture_rate'] > 90), ['pokedex_number', 'name', 'hp','abilities', 'capture_rate']].reset_index(drop=True)
# Out:
#    pokedex_number       name  hp                                 abilities  \
# 0             175     Togepi  35  ['Hustle', 'Serene Grace', 'Super Luck']
# 1             519     Pidove  50    ['Big Pecks', 'Super Luck', 'Rivalry']
# 2             520  Tranquill  62    ['Big Pecks', 'Super Luck', 'Rivalry']
#
#    capture_rate
# 0         190.0
# 1         255.0
# 2         120.0
